# %% [markdown]
# <a href="https://colab.research.google.com/github/Sequro/IntroAD/blob/Joseph/TestCSVs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('sample_data/climate-change_cri.csv')

data=pd.DataFrame(df)
data
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1        Costa Rica            CRI        2021
# 2        Costa Rica            CRI        2020
# 3        Costa Rica            CRI        2019
# 4        Costa Rica            CRI        2018
# ...             ...            ...         ...
# 1967     Costa Rica            CRI        1964
# 1968     Costa Rica            CRI        1963
# 1969     Costa Rica            CRI        1962
# 1970     Costa Rica            CRI        1961
# 1971     Costa Rica            CRI        1960
#
#                                 Indicator Name     Indicator Code  \
# 0                              #indicator+name    #indicator+code
# 1                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 2                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 3                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# ...

# %%
# año mínimo y máximo en el CSV
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
year_range = df['Year'].min(), df['Year'].max()
print(f"El rango de años en el CSV es: {year_range[0]} - {year_range[1]}")
# Out:
# El rango de años en el CSV es: 1960.0 - 2023.0

# %%
#Indicadores dentro del cambio climatico en Costa Rica
indicators=data['Indicator Name'].unique()
indicators
# Out:
# array(['#indicator+name', 'Agricultural land (sq. km)',
#        'Agricultural land (% of land area)',
#        'Arable land (% of land area)',
#        'Rural land area where elevation is below 5 meters (sq. km)',
#        'Rural land area where elevation is below 5 meters (% of total land area)',
#        'Urban land area where elevation is below 5 meters (sq. km)',
#        'Urban land area where elevation is below 5 meters (% of total land area)',
#        'Land area where elevation is below 5 meters (% of total land area)',
#        'Forest area (sq. km)', 'Forest area (% of land area)',
#        'Average precipitation in depth (mm per year)',
#        'Cereal yield (kg per hectare)',
#        'Foreign direct investment, net inflows (% of GDP)',
#        'Access to electricity (% of population)',
#        'Renewable energy consumption (% of total final energy consumption)',
#        'CO2 intensity (kg per kg of oil equivalent energy use)',
# ...

# %%
# Datos de Costa Rica antes de 2017.
costa_rica_antes_2017 =data.loc[(data['Year'] < '2017')]
costa_rica_antes_2017
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 6        Costa Rica            CRI        2016
# 7        Costa Rica            CRI        2015
# 8        Costa Rica            CRI        2014
# 9        Costa Rica            CRI        2013
# ...             ...            ...         ...
# 1967     Costa Rica            CRI        1964
# 1968     Costa Rica            CRI        1963
# 1969     Costa Rica            CRI        1962
# 1970     Costa Rica            CRI        1961
# 1971     Costa Rica            CRI        1960
#
#                                 Indicator Name     Indicator Code  \
# 0                              #indicator+name    #indicator+code
# 6                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 7                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 8                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# ...

# %%
# Datos con el indicador "Agricultural land (sq. km)".
data_agri = data.loc[(data['Indicator Name'] == "Agricultural land (sq. km)")]
data_agri
# Out:
#    Country Name Country ISO3  Year              Indicator Name  \
# 1    Costa Rica          CRI  2021  Agricultural land (sq. km)
# 2    Costa Rica          CRI  2020  Agricultural land (sq. km)
# 3    Costa Rica          CRI  2019  Agricultural land (sq. km)
# 4    Costa Rica          CRI  2018  Agricultural land (sq. km)
# 5    Costa Rica          CRI  2017  Agricultural land (sq. km)
# ..          ...          ...   ...                         ...
# 57   Costa Rica          CRI  1965  Agricultural land (sq. km)
# 58   Costa Rica          CRI  1964  Agricultural land (sq. km)
# 59   Costa Rica          CRI  1963  Agricultural land (sq. km)
# 60   Costa Rica          CRI  1962  Agricultural land (sq. km)
# 61   Costa Rica          CRI  1961  Agricultural land (sq. km)
#
#     Indicator Code  Value
# 1   AG.LND.AGRI.K2  18110
# 2   AG.LND.AGRI.K2  17860
# 3   AG.LND.AGRI.K2  17760
# 4   AG.LND.AGRI.K2  17825
# 5   AG.LND.AGRI.K2  17810
# ..             ...    ...
# ...

# %%
# Tendencia de "Agricultural land (sq. km)" para Costa Rica entre 2015 y 2020.
trend_2015_2020 = data_agri.loc[(data_agri['Year'] >= '2015') & (data_agri['Year'] <= '2020')][['Year', 'Value']]
trend_2015_2020
# Out:
#    Year  Value
# 2  2020  17860
# 3  2019  17760
# 4  2018  17825
# 5  2017  17810
# 6  2016  17770
# 7  2015  17915

# %%
# area forestal promedio en Costa Rica
promedio_forest = data[data['Indicator Name'] == 'Forest area (sq. km)']['Value']
forest_data = pd.to_numeric( promedio_forest, errors='coerce')
forest_data.mean()
# Out:
# 29068.09375

# %%
# Toda la informacion del año 1960
data60=data.loc[(data['Year']==1960)]
print('Costa Rica anno 1960 \n')
print(data60[['Country Name', 'Year', 'Indicator Code','Value']])

# Porcentaje de crecimiento de la poblacion del 1980 a 2010
print('\n Porcentaje crecimiento de poblacion en Costa Rica \n')
dataPop=data.loc[((data['Indicator Name']=='Population growth (annual %)') & (data['Year']>1980) & (data['Year']<2010))]
print(dataPop.sort_values(by=['Value'], ascending=True)[['Country Name', 'Year', 'Value']])
# Out:
# Costa Rica anno 1960
#
#      Country Name  Year     Indicator Code         Value
# 590    Costa Rica  1960  EN.ATM.CO2E.GF.KT  0.000000e+00
# 647    Costa Rica  1960  EN.ATM.CO2E.GF.ZS  0.000000e+00
# 766    Costa Rica  1960  EN.ATM.CO2E.LF.KT  4.913780e+02
# 823    Costa Rica  1960  EN.ATM.CO2E.LF.ZS  1.000000e+02
# 973    Costa Rica  1960  EN.ATM.CO2E.SF.KT  0.000000e+00
# 1030   Costa Rica  1960  EN.ATM.CO2E.SF.ZS  0.000000e+00
# 1349   Costa Rica  1960  EN.URB.MCTY.TL.ZS  1.706838e+01
# 1452   Costa Rica  1960     NV.AGR.TOTL.ZS  2.635203e+01
# 1612   Costa Rica  1960        SH.DYN.MORT  9.600000e+01
# 1782   Costa Rica  1960        SP.POP.TOTL  1.346302e+06
# 1907   Costa Rica  1960        SP.URB.TOTL  4.611620e+05
# 1970   Costa Rica  1960  SP.URB.TOTL.IN.ZS  3.425400e+01
#
#  Porcentaje crecimiento de poblacion en Costa Rica
#
#      Country Name  Year     Value
# 1671   Costa Rica  2009  1.350394
# 1672   Costa Rica  2008  1.384554
# 1673   Costa Rica  2007  1.402737
# ...

# %%
agricultural = data[data['Indicator Name'] == "Agricultural land (sq. km)"]
# 3. ¿Cuáles son los años con el mayor y menor uso de tierras agrícolas en Costa Rica?

max_agricultural_year = agricultural.loc[agricultural['Value'].idxmax()][['Year', 'Value']]
print("Mayor uso de tierras agricolas: ",max_agricultural_year)
min_agricultural_year = agricultural.loc[agricultural['Value'].idxmin()][['Year', 'Value']]
print("Menor uso de tierras agricolas: ",min_agricultural_year)
# Out:
# Mayor uso de tierras agricolas:  Year      1984
# Value    27480
# Name: 38, dtype: object
# Menor uso de tierras agricolas:  Year      1961
# Value    13950
# Name: 61, dtype: object

# %%
# Indicador "CO2 emissions (kt)" para 2020.
agricultural_2020 = data.loc[(data['Year'] == '2020' ) & (data['Indicator Name'] == "CO2 emissions (kt)")]
agricultural_2020
# Out:
#     Country Name Country ISO3  Year      Indicator Name  Indicator Code  \
# 680   Costa Rica          CRI  2020  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#       Value
# 680  6967.4

# %%
# Indicador "CO2 emissions (kt)" para 1990.
agricultural_1990 = data.loc[(data['Year'] == '1990') & (data['Indicator Name'] == "CO2 emissions (kt)")]
agricultural_1990
# Out:
#     Country Name Country ISO3  Year      Indicator Name  Indicator Code  \
# 710   Costa Rica          CRI  1990  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#       Value
# 710  2871.2
