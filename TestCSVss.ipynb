# %% [markdown]
# <a href="https://colab.research.google.com/github/Sequro/IntroAD/blob/main/TestCSVss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/climate-change_cri.csv')

data=pd.DataFrame(df)
data
# Out:
#      Country Name Country ISO3  Year  \
# 0      Costa Rica          CRI  2021
# 1      Costa Rica          CRI  2020
# 2      Costa Rica          CRI  2019
# 3      Costa Rica          CRI  2018
# 4      Costa Rica          CRI  2017
# ...           ...          ...   ...
# 1966   Costa Rica          CRI  1964
# 1967   Costa Rica          CRI  1963
# 1968   Costa Rica          CRI  1962
# 1969   Costa Rica          CRI  1961
# 1970   Costa Rica          CRI  1960
#
#                                 Indicator Name     Indicator Code      Value
# 0                   Agricultural land (sq. km)     AG.LND.AGRI.K2  18110.000
# 1                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17860.000
# 2                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17760.000
# 3                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17825.000
# 4                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17810.000
# ...

# %%
#Indicadores dentro del cambio climatico en Costa Rica
indicators=data['Indicator Name'].unique()
indicators

# %%
# Datos del año 2019.
datos_2019 = data.loc[(data['Year'] == '2019')]
datos_2019
# Out:
#      Country Name Country ISO3  Year  \
# 3      Costa Rica          CRI  2019
# 64     Costa Rica          CRI  2019
# 125    Costa Rica          CRI  2019
# 201    Costa Rica          CRI  2019
# 233    Costa Rica          CRI  2019
# 264    Costa Rica          CRI  2019
# 326    Costa Rica          CRI  2019
# 388    Costa Rica          CRI  2019
# 440    Costa Rica          CRI  2019
# 461    Costa Rica          CRI  2019
# 650    Costa Rica          CRI  2019
# 681    Costa Rica          CRI  2019
# 826    Costa Rica          CRI  2019
# 857    Costa Rica          CRI  2019
# 888    Costa Rica          CRI  2019
# 1102   Costa Rica          CRI  2019
# 1160   Costa Rica          CRI  2019
# 1213   Costa Rica          CRI  2019
# 1291   Costa Rica          CRI  2019
# 1352   Costa Rica          CRI  2019
# 1361   Costa Rica          CRI  2019
# 1372   Costa Rica          CRI  2019
# 1379   Costa Rica          CRI  2019
# 1386   Costa Rica          CRI  2019
# ...

# %%
# Indicador "CO2 emissions (kt)" para 2018.
agricultural_2018 = data.loc[(data['Year'] == '2018') & (data['Indicator Name'] == "CO2 emissions (kt)")]
agricultural_2018
# Out:
#     Country Name Country ISO3  Year      Indicator Name  Indicator Code  \
# 682   Costa Rica          CRI  2018  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#       Value
# 682  8166.6

# %%
# Datos de Costa Rica antes de 2017.
costa_rica = data.loc[(data['Country Name'] == "Costa Rica")]
costa_rica_antes_2017 = costa_rica.loc[(costa_rica['Year'] < '2017')]
costa_rica_antes_2017
# Out:
#      Country Name Country ISO3  Year  \
# 6      Costa Rica          CRI  2016
# 7      Costa Rica          CRI  2015
# 8      Costa Rica          CRI  2014
# 9      Costa Rica          CRI  2013
# 10     Costa Rica          CRI  2012
# ...           ...          ...   ...
# 1967   Costa Rica          CRI  1964
# 1968   Costa Rica          CRI  1963
# 1969   Costa Rica          CRI  1962
# 1970   Costa Rica          CRI  1961
# 1971   Costa Rica          CRI  1960
#
#                                 Indicator Name     Indicator Code   Value
# 6                   Agricultural land (sq. km)     AG.LND.AGRI.K2   17770
# 7                   Agricultural land (sq. km)     AG.LND.AGRI.K2   17915
# 8                   Agricultural land (sq. km)     AG.LND.AGRI.K2   17850
# 9                   Agricultural land (sq. km)     AG.LND.AGRI.K2   18010
# 10                  Agricultural land (sq. km)     AG.LND.AGRI.K2   18120
# ...

# %%
# Datos con el indicador "Agricultural land (sq. km)".
data_agri = data.loc[(data['Indicator Name'] == "Agricultural land (sq. km)")]
data_agri
# Out:
#    Country Name Country ISO3  Year              Indicator Name  \
# 1    Costa Rica          CRI  2021  Agricultural land (sq. km)
# 2    Costa Rica          CRI  2020  Agricultural land (sq. km)
# 3    Costa Rica          CRI  2019  Agricultural land (sq. km)
# 4    Costa Rica          CRI  2018  Agricultural land (sq. km)
# 5    Costa Rica          CRI  2017  Agricultural land (sq. km)
# ..          ...          ...   ...                         ...
# 57   Costa Rica          CRI  1965  Agricultural land (sq. km)
# 58   Costa Rica          CRI  1964  Agricultural land (sq. km)
# 59   Costa Rica          CRI  1963  Agricultural land (sq. km)
# 60   Costa Rica          CRI  1962  Agricultural land (sq. km)
# 61   Costa Rica          CRI  1961  Agricultural land (sq. km)
#
#     Indicator Code  Value
# 1   AG.LND.AGRI.K2  18110
# 2   AG.LND.AGRI.K2  17860
# 3   AG.LND.AGRI.K2  17760
# 4   AG.LND.AGRI.K2  17825
# 5   AG.LND.AGRI.K2  17810
# ..             ...    ...
# ...

# %%
# Tendencia de "Agricultural land (sq. km)" para Costa Rica entre 2015 y 2020.
trend_2015_2020 = data_agri.loc[(data_agri['Year'] >= '2015') & (data_agri['Year'] <= '2020')][['Year', 'Value']]
trend_2015_2020
# Out:
#    Year  Value
# 2  2020  17860
# 3  2019  17760
# 4  2018  17825
# 5  2017  17810
# 6  2016  17770
# 7  2015  17915

# %%
# area forestal promedio en Costa Rica
promedio_forest = data[data['Indicator Name'] == 'Forest area (sq. km)']['Value']
forest_data = pd.to_numeric( promedio_forest, errors='coerce')
forest_data.mean()
# Out:
# 29068.09375

# %%
# año mínimo y máximo en el CSV
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
year_range = df['Year'].min(), df['Year'].max()
print(f"El rango de años en el CSV es: {year_range[0]} - {year_range[1]}")
# Out:
# El rango de años en el CSV es: 1960.0 - 2023.0

# %%
#Niveles de consumo de energia verde

Consume_green_energy=data.loc[(data['Indicator Name'] == 'Renewable energy consumption (% of total final energy consumption)') & (data['Value'])]
print(Consume_green_energy.sort_values(by='Year',ascending=False))

# %%
#Niveles oxido nitroso
Oxido_nitroso_toneladas_Metricas = data.loc[(data['Indicator Name'] == "Nitrous oxide emissions (thousand metric tons of CO2 equivalent)")]
Oxido_nitroso_toneladas_Metricas
