# %% [markdown]
# <a href="https://colab.research.google.com/github/Sequro/IntroAD/blob/main/TestCSVs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('sample_data/climate-change_cri.csv')

data=pd.DataFrame(df)
data
# Out:
#      Country Name Country ISO3  Year  \
# 0      Costa Rica          CRI  2021
# 1      Costa Rica          CRI  2020
# 2      Costa Rica          CRI  2019
# 3      Costa Rica          CRI  2018
# 4      Costa Rica          CRI  2017
# ...           ...          ...   ...
# 1966   Costa Rica          CRI  1964
# 1967   Costa Rica          CRI  1963
# 1968   Costa Rica          CRI  1962
# 1969   Costa Rica          CRI  1961
# 1970   Costa Rica          CRI  1960
#
#                                 Indicator Name     Indicator Code      Value
# 0                   Agricultural land (sq. km)     AG.LND.AGRI.K2  18110.000
# 1                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17860.000
# 2                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17760.000
# 3                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17825.000
# 4                   Agricultural land (sq. km)     AG.LND.AGRI.K2  17810.000
# ...

# %%
#Indicadores dentro del cambio climatico en Costa Rica
indicators=data['Indicator Name'].unique()
indicators
# Out:
# array(['#indicator+name', 'Agricultural land (sq. km)',
#        'Agricultural land (% of land area)',
#        'Arable land (% of land area)',
#        'Rural land area where elevation is below 5 meters (sq. km)',
#        'Rural land area where elevation is below 5 meters (% of total land area)',
#        'Urban land area where elevation is below 5 meters (sq. km)',
#        'Urban land area where elevation is below 5 meters (% of total land area)',
#        'Land area where elevation is below 5 meters (% of total land area)',
#        'Forest area (sq. km)', 'Forest area (% of land area)',
#        'Average precipitation in depth (mm per year)',
#        'Cereal yield (kg per hectare)',
#        'Foreign direct investment, net inflows (% of GDP)',
#        'Access to electricity (% of population)',
#        'Renewable energy consumption (% of total final energy consumption)',
#        'CO2 intensity (kg per kg of oil equivalent energy use)',
# ...

# %%
#Comparacion de cada 10 años sobre todos los indicadores del CO2
print('\n Comparacion del CO2 cada 10 años \n')
print(' \n Año 1990 ')
dataCO2_80=data.loc[((data['Indicator Name'].str.contains('CO2')) & (data['Year']==1990))]
print(dataCO2_80[[ 'Year', 'Indicator Code','Value']])

print(' \n Año 2000')
dataCO2_00=data.loc[((data['Indicator Name'].str.contains('CO2')) & (data['Year']==2000))]
print(dataCO2_00[[ 'Year', 'Indicator Code','Value']])

print(' \n Año 2010')
dataCO2_10=data.loc[((data['Indicator Name'].str.contains('CO2')) & (data['Year']==2010))]
print(dataCO2_10[[ 'Year', 'Indicator Code','Value']])

print(' \n Año 2020')
dataCO2_20=data.loc[((data['Indicator Name'].str.contains('CO2')) & (data['Year']==2020))]
print(dataCO2_20[[ 'Year', 'Indicator Code','Value']])
# Out:
#  Comparacion del CO2 cada 10 años
#
#
#  Año 1990
#       Year        Indicator Code        Value
# 514   1990     EN.ATM.CO2E.EG.ZS     1.710948
# 560   1990     EN.ATM.CO2E.GF.KT     0.000000
# 617   1990     EN.ATM.CO2E.GF.ZS     0.000000
# 678   1990     EN.ATM.CO2E.KD.GD     0.152351
# 709   1990        EN.ATM.CO2E.KT  2871.200000
# 736   1990     EN.ATM.CO2E.LF.KT  2647.574000
# 793   1990     EN.ATM.CO2E.LF.ZS    92.249965
# 854   1990        EN.ATM.CO2E.PC     0.909110
# 885   1990     EN.ATM.CO2E.PP.GD     0.183211
# 916   1990  EN.ATM.CO2E.PP.GD.KD     0.092667
# 943   1990     EN.ATM.CO2E.SF.KT     0.000000
# 1000  1990     EN.ATM.CO2E.SF.ZS     0.000000
# 1057  1990     EN.ATM.GHGO.KT.CE    12.397530
# 1130  1990     EN.ATM.GHGT.KT.CE  8492.885741
# 1157  1990     EN.ATM.HFCG.KT.CE     0.000000
# 1188  1990     EN.ATM.METH.KT.CE  3976.460000
# 1241  1990     EN.ATM.NOXE.KT.CE  1622.765883
# 1268  1990     EN.ATM.PFCG.KT.CE     0.000000
# ...

# %%
#Comparacion del porcentaje del cosumo de energia renobable cada 10 años
print('\n Comparacion del porcentaje del cosumo de energia renobable cada 10 años \n')
print(' \n Año 1990 ')
datarenewcomp90=data.loc[(data['Indicator Name']=='Renewable energy consumption (% of total final energy consumption)')&(data['Year']==1990)]
print(datarenewcomp90[[ 'Year', 'Indicator Code','Value']])

print(' \n Año 2000 ')
datarenewcomp00=data.loc[(data['Indicator Name']=='Renewable energy consumption (% of total final energy consumption)')&(data['Year']==2000)]
print(datarenewcomp00[[ 'Year', 'Indicator Code','Value']])

print(' \n Año 2010 ')
datarenewcomp10=data.loc[(data['Indicator Name']=='Renewable energy consumption (% of total final energy consumption)')&(data['Year']==2010)]
print(datarenewcomp10[[ 'Year', 'Indicator Code','Value']])

print(' \n Año 2020 ')
datarenewcomp20=data.loc[(data['Indicator Name']=='Renewable energy consumption (% of total final energy consumption)')&(data['Year']==2020)]
print(datarenewcomp20[[ 'Year', 'Indicator Code','Value']])
# Out:
#  Comparacion del porcentaje del cosumo de energia renobable cada 10 años
#
#
#  Año 1990
#      Year  Indicator Code  Value
# 489  1990  EG.FEC.RNEW.ZS  45.37
#
#  Año 2000
#      Year  Indicator Code  Value
# 479  2000  EG.FEC.RNEW.ZS  32.95
#
#  Año 2010
#      Year  Indicator Code  Value
# 469  2010  EG.FEC.RNEW.ZS  40.39
#
#  Año 2020
#      Year  Indicator Code  Value
# 459  2020  EG.FEC.RNEW.ZS  36.43

# %%
#¿Cuáles son los años con el mayor y menor uso de tierras agrícolas en Costa Rica?
agricultural = data[data['Indicator Name'] == "Agricultural land (sq. km)"]

max_agricultural_year = agricultural.loc[agricultural['Value'].idxmax()][['Year', 'Value']]
print("Mayor uso de tierras agricolas:\n",max_agricultural_year[['Year', 'Value']])
min_agricultural_year = agricultural.loc[agricultural['Value'].idxmin()][['Year', 'Value']]
print("Menor uso de tierras agricolas:\n",min_agricultural_year[['Year', 'Value']])
# Out:
# Mayor uso de tierras agricolas:
#  Year        1984
# Value    27480.0
# Name: 37, dtype: object
# Menor uso de tierras agricolas:
#  Year        1961
# Value    13950.0
# Name: 60, dtype: object

# %%
# Area forestal promedio en Costa Rica
promedio_forest = data[data['Indicator Name'] == 'Forest area (sq. km)']['Value']
forest_data = pd.to_numeric( promedio_forest, errors='coerce')
print('\n El promedio de area forestal en Costa Rica es de:', forest_data.mean())
# Out:
#  El promedio de area forestal en Costa Rica es de: 29068.09375

# %%
# Datos de Costa Rica antes de 2017.
print('\n Datos de Costa Rica antes de 2017 \n')
databef17 = data.loc[(data['Year'] < 2017)]
print(databef17.sort_values(by='Year', ascending=True)[[ 'Year', 'Indicator Code','Value']])
# Out:
#  Datos de Costa Rica antes de 2017
#
#
#  Año 2017
#       Year     Indicator Code         Value
# 1970  1960  SP.URB.TOTL.IN.ZS     34.254000
# 766   1960  EN.ATM.CO2E.LF.KT    491.378000
# 823   1960  EN.ATM.CO2E.LF.ZS    100.000000
# 590   1960  EN.ATM.CO2E.GF.KT      0.000000
# 973   1960  EN.ATM.CO2E.SF.KT      0.000000
# ...    ...                ...           ...
# 1507  2016     SE.PRM.CMPT.ZS     94.578148
# 534   2016  EN.ATM.CO2E.GF.KT      0.000000
# 1396  2016     NV.AGR.TOTL.ZS      4.914356
# 1556  2016        SH.DYN.MORT      8.900000
# 5     2016     AG.LND.AGRI.K2  17770.000000
#
# [1798 rows x 3 columns]

# %%
# Datos de Costa Rica despues de 2017.
print('\n Datos de Costa Rica despues del 2017 \n')
dataaft17 = costa_rica.loc[(costa_rica['Year'] > 2017)]
print(dataaft17.sort_values(by='Year', ascending=True)[[ 'Year', 'Indicator Code','Value']])
# Out:
#  Datos de Costa Rica despues del 2017
#
#       Year        Indicator Code        Value
# 1291  2018     EN.URB.MCTY.TL.ZS    26.935462
# 461   2018        EG.FEC.RNEW.ZS    33.130000
# 650   2018     EN.ATM.CO2E.KD.GD     0.129912
# 681   2018        EN.ATM.CO2E.KT  8166.600000
# 826   2018        EN.ATM.CO2E.PC     1.620121
# ...    ...                   ...          ...
# 1390  2022        NV.AGR.TOTL.ZS     4.140074
# 1658  2022           SP.POP.GROW     0.520031
# 1287  2022     EN.URB.MCTY.TL.ZS    27.820335
# 384   2022  BX.KLT.DINV.WD.GD.ZS     5.305043
# 1286  2023     EN.URB.MCTY.TL.ZS    28.049510
#
# [139 rows x 3 columns]
