# %% [markdown]
# <a href="https://colab.research.google.com/github/Sequro/IntroAD/blob/Joseph/2ndodatasetsconproyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('sample_data/climate-change_cri.csv')

data=pd.DataFrame(df)
data
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1        Costa Rica            CRI        2021
# 2        Costa Rica            CRI        2020
# 3        Costa Rica            CRI        2019
# 4        Costa Rica            CRI        2018
# ...             ...            ...         ...
# 1967     Costa Rica            CRI        1964
# 1968     Costa Rica            CRI        1963
# 1969     Costa Rica            CRI        1962
# 1970     Costa Rica            CRI        1961
# 1971     Costa Rica            CRI        1960
#
#                                 Indicator Name     Indicator Code  \
# 0                              #indicator+name    #indicator+code
# 1                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 2                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 3                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# ...

# %%
import pandas as pd
df['Value'] = pd.to_numeric (df['Value'], errors= 'coerce')
registro_emisiones= df.loc[(df['Indicator Name'].isin(['CO2 emissions from liquid fuel consumption (kt)','CO2 emissions from solid fuel consumption (kt)'])) & (df['Value'].notnull())]
promedio_emisiones = registro_emisiones.groupby(['Indicator Name'])['Value'].mean().to_frame()
promedio_emisiones= promedio_emisiones.round(2)
promedio_emisiones = promedio_emisiones.rename(columns={'Value': 'Promedio de emisiones de CO2'})
print(f'Promedio: \n: ', promedio_emisiones)
# Out:
# Promedio:
# :                                                   Promedio de emisiones de CO2
# Indicator Name
# CO2 emissions from liquid fuel consumption (kt)                       3410.44
# CO2 emissions from solid fuel consumption (kt)                          73.34
